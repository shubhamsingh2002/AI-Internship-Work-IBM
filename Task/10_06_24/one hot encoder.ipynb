# %%
import pandas as pd
df = pd.read_csv("predict.csv")
df.head(1)
# Out:
#    Area Locality    Price
# 0   550  Station  1200000

# %%
df.info
# Out:
# <bound method DataFrame.info of    Area Locality    Price
# 0   550  Station  1200000
# 1   600   Center  1200000
# 2   650      Old  1400000
# 3  1200  Station  2400000
# 4  1250   Center  3000000
# 5   800   Center  2000000
# 6   700      Old  1450000
# 7   750   Center  1700000
# 8   825  Station  2000000
# 9   900      Old  1900000>

# %%
#dummy
#one hot encoding

# %%
dummy=pd.get_dummies(df.Locality)
dummy
# Out:
#    Center    Old  Station
# 0   False  False     True
# 1    True  False    False
# 2   False   True    False
# 3   False  False     True
# 4    True  False    False
# 5    True  False    False
# 6   False   True    False
# 7    True  False    False
# 8   False  False     True
# 9   False   True    False

# %%
dummy.to_csv("dummy.csv")

# %%
merged = pd.concat([df,dummy],axis='columns')
merged
# Out:
#    Area Locality    Price  Center    Old  Station
# 0   550  Station  1200000   False  False     True
# 1   600   Center  1200000    True  False    False
# 2   650      Old  1400000   False   True    False
# 3  1200  Station  2400000   False  False     True
# 4  1250   Center  3000000    True  False    False
# 5   800   Center  2000000    True  False    False
# 6   700      Old  1450000   False   True    False
# 7   750   Center  1700000    True  False    False
# 8   825  Station  2000000   False  False     True
# 9   900      Old  1900000   False   True    False

# %%
a= merged.drop(['Locality'],axis='columns')
a
# Out:
#    Area    Price  Center    Old  Station
# 0   550  1200000   False  False     True
# 1   600  1200000    True  False    False
# 2   650  1400000   False   True    False
# 3  1200  2400000   False  False     True
# 4  1250  3000000    True  False    False
# 5   800  2000000    True  False    False
# 6   700  1450000   False   True    False
# 7   750  1700000    True  False    False
# 8   825  2000000   False  False     True
# 9   900  1900000   False   True    False

# %%
a.replace([True,False],[1,0],inplace=True)
a
# Out:
# C:\Users\SHUBH\AppData\Local\Temp\ipykernel_6152\4090831916.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   a.replace([True,False],[1,0],inplace=True)
#    Area    Price  Center  Old  Station
# 0   550  1200000       0    0        1
# 1   600  1200000       1    0        0
# 2   650  1400000       0    1        0
# 3  1200  2400000       0    0        1
# 4  1250  3000000       1    0        0
# 5   800  2000000       1    0        0
# 6   700  1450000       0    1        0
# 7   750  1700000       1    0        0
# 8   825  2000000       0    0        1
# 9   900  1900000       0    1        0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
a = df

# %%
a.Locality= le.fit_transform(a.Locality)
a
# Out:
#    Area  Locality    Price
# 0   550         2  1200000
# 1   600         0  1200000
# 2   650         1  1400000
# 3  1200         2  2400000
# 4  1250         0  3000000
# 5   800         0  2000000
# 6   700         1  1450000
# 7   750         0  1700000
# 8   825         2  2000000
# 9   900         1  1900000

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(a.drop('Price',axis='columns'),a.Price)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 297.41641881968826

# %%
model.coef_
# Out:
# array([  2292.90142258, -68009.81832515])

# %%
model.predict([[1500, 2]])
# Out:
# C:\Users\SHUBH\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3303629.91364174])

# %%
model.predict([[1500, 1]])
# Out:
# C:\Users\SHUBH\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3371639.73196689])
