# %%
import pandas as pd
df = pd.read_csv('student.csv')
df.head()
# Out:
#    Hours  Previous  Activities  Sleep  Practiced  Index
# 0      7         99        Yes      9          1     91
# 1      4         82         No      4          2     65
# 2      8         51        Yes      7          2     45
# 3      5         52        Yes      5          2     36
# 4      7         75         No      8          5     66

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
a = df
a.Activities = le.fit_transform(a.Activities)
a
# Out:
#       Hours  Previous   Activities  Sleep  Practiced  Index
# 0         7         99           1      9          1     91
# 1         4         82           0      4          2     65
# 2         8         51           1      7          2     45
# 3         5         52           1      5          2     36
# 4         7         75           0      8          5     66
# ...     ...        ...         ...    ...        ...    ...
# 9995      1         49           1      4          2     23
# 9996      7         64           1      8          5     58
# 9997      6         83           1      8          5     74
# 9998      9         97           1      7          0     95
# 9999      7         74           0      8          1     64
#
# [10000 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x = a.drop('Index',axis='columns')

# %%
y = a['Index']

# %%
y
# Out:
# 0       91
# 1       65
# 2       45
# 3       36
# 4       66
#         ..
# 9995    23
# 9996    58
# 9997    74
# 9998    95
# 9999    64
# Name: Index, Length: 10000, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20)

# %%
x_train
# Out:
#       Hours  Previous   Activities  Sleep  Practiced
# 2879      8         64           1      9          6
# 8581      9         60           1      6          1
# 8379      6         77           0      6          1
# 6295      5         53           0      8          2
# 7172      9         45           0      9          4
# ...     ...        ...         ...    ...        ...
# 2993      4         94           1      4          7
# 6434      4         50           1      9          8
# 2451      8         98           0      4          9
# 2464      5         74           1      7          1
# 816       9         63           0      9          3
#
# [8000 rows x 5 columns]

# %%
x_test
# Out:
#       Hours  Previous   Activities  Sleep  Practiced
# 8129      4         70           1      6          5
# 6756      5         70           1      9          7
# 1742      6         92           0      4          2
# 1498      6         49           0      6          2
# 8994      7         47           0      8          0
# ...     ...        ...         ...    ...        ...
# 8765      3         80           0      4          2
# 2473      7         64           0      4          3
# 7028      2         73           1      8          2
# 3560      9         74           1      6          5
# 840       2         51           0      6          9
#
# [2000 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([53.09544251, 57.78605274, 79.01332921, ..., 50.81119706,
#        71.46887102, 28.12561033])

# %%
df1 = pd.DataFrame({'Original':y_test,'Predicted':y_pred})

# %%
df1
# Out:
#       Original  Predicted
# 8129        53  53.095443
# 6756        57  57.786053
# 1742        80  79.013329
# 1498        36  36.166421
# 8994        41  37.561409
# ...        ...        ...
# 8765        59  58.208776
# 2473        46  53.540835
# 7028        50  50.811197
# 3560        69  71.468871
# 840         27  28.125610
#
# [2000 rows x 2 columns]

# %%
#Training Score
model.score(x_train,y_train)
# Out:
# 0.988665788847039

# %%
#Test score
model.score(x_test,y_test)
# Out:
# 0.989064080271865

# %%
import sklearn
import sklearn.metrics as metrics

# %%
print("Mean Squared Error")
metrics.mean_
