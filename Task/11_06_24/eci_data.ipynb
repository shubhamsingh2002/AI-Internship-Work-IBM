# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('electiondata4.csv')
df
# Out:
#        ref                      state                  constituency  \
# 0        1  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 1        2  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 2        3  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 3        4  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 4        5  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# ...    ...                        ...                           ...
# 8897  8898                  Jharkhand                      Godda(3)
# 8898  8899                  Jharkhand                      Godda(3)
# 8899  8900                  Jharkhand                      Godda(3)
# 8900  8901                  Jharkhand                      Godda(3)
# 8901  8902                  Jharkhand                      Godda(3)
#
#      won status winner_votes     (votes)                Name  \
# 0           won       102436   (+ 24396)     BISHNU PADA RAY
# ...

# %%
andaman_and_nicobar = pd.DataFrame(andaman_and_nicobar)

# %%
andaman_and_nicobar
# Out:
#     ref                      state                  constituency won status  \
# 0     1  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)        won
# 1     2  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)       lost
# 2     3  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)       lost
# 3     4  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)       lost
# 4     5  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)       lost
# 5     6  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)       lost
# 6     7  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)       lost
# 7     8  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)       lost
# 8     9  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)       lost
# 9    10  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)       lost
# 10   11  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)       lost
# ...

# %%
PartyName = andaman_and_nicobar['Party_Name']
values = andaman_and_nicobar['winner_votes']
plt.figure(figsize=(10, 8)) 
plt.bar(PartyName, values)
plt.xlabel("Party")
plt.ylabel("Votes Won")
plt.title("Votes Won by Different Parties in an Election")
plt.xticks(rotation=45) 
plt.tight_layout() 
plt.show()

# %%
df
# Out:
#        ref                      state                  constituency  \
# 0        1  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 1        2  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 2        3  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 3        4  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# 4        5  Andaman & Nicobar Islands  Andaman & Nicobar Islands(1)
# ...    ...                        ...                           ...
# 8897  8898                  Jharkhand                      Godda(3)
# 8898  8899                  Jharkhand                      Godda(3)
# 8899  8900                  Jharkhand                      Godda(3)
# 8900  8901                  Jharkhand                      Godda(3)
# 8901  8902                  Jharkhand                      Godda(3)
#
#      won status winner_votes     (votes)                Name  \
# 0           won       102436   (+ 24396)     BISHNU PADA RAY
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8902 entries, 0 to 8901
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ref           8902 non-null   int64
#  1   state         8902 non-null   object
#  2   constituency  8902 non-null   object
#  3   won status    8360 non-null   object
#  4   winner_votes  8902 non-null   object
#  5   (votes)       8901 non-null   object
#  6   Name          8902 non-null   object
#  7   Party_Name    8902 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 556.5+ KB
