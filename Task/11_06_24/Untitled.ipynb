# %%
import pandas as pd

# %%
df = pd.read_csv('PartyData.csv')
df
df1= pd.DataFrame(df)
df1
# Out:
#      ref wonstatus totalvotes    winvotes                             name  \
# 0      1       won     477033   (+ 70703)                     RAVIKUMAR. D
# 1      2       won     303859   (+ 44111)          DR. RAJ KUMAR CHABBEWAL
# 2      3       won     364085  (+ 172560)         GURMEET SINGH MEET HAYER
# 3      4       won     529382   (+ 59808)                    SUDAMA PRASAD
# 4      5       won     313217   (+ 10846)             MALVINDER SINGH KANG
# ..   ...       ...        ...         ...                              ...
# 538  539       won     567043   (+ 89634)                       VEENA DEVI
# 539  540       won     579786  (+ 187251)                        SHAMBHAVI
# 540  541       won     567556   (+ 23847)  RAJESH RANJAN ALIAS PAPPU YADAV
# 541  542       won     615718  (+ 170105)                    CHIRAG PASWAN
# 542  543       won     772774  (+ 541229)  VISHNU DATT SHARMA (V.D.SHARMA)
#
#                                              partyname
# ...

# %%
df1.head(5)
# Out:
#    ref wonstatus totalvotes    winvotes                      name  \
# 0    1       won     477033   (+ 70703)              RAVIKUMAR. D
# 1    2       won     303859   (+ 44111)   DR. RAJ KUMAR CHABBEWAL
# 2    3       won     364085  (+ 172560)  GURMEET SINGH MEET HAYER
# 3    4       won     529382   (+ 59808)             SUDAMA PRASAD
# 4    5       won     313217   (+ 10846)      MALVINDER SINGH KANG
#
#                                            partyname
# 0                     Viduthalai Chiruthaigal Katchi
# 1                                    Aam Aadmi Party
# 2                                    Aam Aadmi Party
# 3  Communist Party of India  (Marxist-Leninist)  ...
# 4                                    Aam Aadmi Party

# %%
import matplotlib.pyplot as plt

# %%
x = df1['partyname']
y = df1['totalvotes']

# %%
plt.figure(figsize=(8, 8))  # Optional: make the plot a bit larger
plt.pie(y,autopct='%1.1f%%', startangle=140)
plt.title('Category Distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 plt.figure(figsize=(8, 8))  # Optional: make the plot a bit larger
# ----> 2 plt.pie(y,autopct='%1.1f%%', startangle=140)
#       3 plt.title('Category Distribution')
#       4 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3676, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3653 @_copy_docstring_and_deprecators(Axes.pie)
#    3654 def pie(
#    3655     x: ArrayLike,
#    (...)
#    3674     data=None,
#    3675 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3676     return gca().pie(
#    3677         x,
#    3678         explode=explode,
# ...
